# %% [markdown]
# # Data Preparation

# %%
import matplotlib.pyplot as plt
import numpy as np

mainX = []
mainY = []

for i in range(20):
    # Generate random data
    x = np.linspace(20, 20, 20)
    y = np.random.rand(20) + x * np.random.rand(20)  # Linear pattern with noise
    
    mainX.extend(x)
    mainY.extend(y)


# Create a line plot
plt.figure(figsize=(10, 6))
#plt.plot(mainX, y, color='blue', marker='o', linestyle='-', linewidth=2, markersize=6, label='Random Linear Pattern')

# Customize plot elements
plt.title('Linear Random Custom Pattern')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %%
plt.plot(mainY[:70])

# %%
len(mainY)
# Out:
# 400

# %% [markdown]
# ---

# %% [markdown]
# # Data Seperation

# %%
XData = mainY[:393]
YData = mainY[7:]

# %%
len(XData), len(YData)
# Out:
# (393, 393)

# %%
def split(list_a, chunk_size):
    for i in range(0, len(list_a)-1, chunk_size):
        yield np.array(list_a[i:i + chunk_size]).astype(np.float32)

chunk_size = 7
XData = (list(split(XData, chunk_size)))
YData = (list(split(YData, chunk_size)))

# %%
len(XData),len(YData)
# Out:
# (56, 56)

# %%
YData.pop()
XData.pop()
# Out:
# array([13.955969 ,  9.840014 ,  7.795982 ,  4.0137315,  2.971019 ,
#        16.424265 , 16.345509 ], dtype=float32)

# %%
YData = np.asarray(YData).astype(np.float32)
XData = np.asarray(XData).astype(np.float32)

# %% [markdown]
# ## Model Building and Training
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from tensorflow import keras
import tensorflow as tf

from tensorflow.keras.optimizers.schedules import ExponentialDecay
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import LearningRateScheduler,ReduceLROnPlateau

from sklearn.model_selection import KFold,GroupKFold
from tensorflow.keras import layers

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
 XData, YData, test_size=0.33, random_state=42)

# %%
YData
# Out:
# array([[ 2.5805695 ,  3.8303173 , 11.128364  , 11.814087  , 15.055831  ,
#         14.140588  , 11.690704  ],
#        [15.035217  ,  2.4426737 , 11.9224    , 19.994892  , 20.415445  ,
#         10.308282  ,  0.81932175],
#        [15.489579  ,  2.5609658 , 16.293991  , 18.679573  ,  0.8237379 ,
#         11.993714  , 18.657146  ],
#        [12.470061  , 14.057403  , 13.12482   ,  4.9630027 , 12.659061  ,
#          2.8294616 , 16.98607   ],
#        [14.602298  ,  8.676418  ,  7.911753  , 10.945277  ,  4.831805  ,
#         18.370037  , 12.136531  ],
#        [ 8.646499  , 14.756029  , 15.686728  ,  0.8609653 , 10.170456  ,
#         15.460404  ,  9.988398  ],
#        [12.905328  ,  6.152447  ,  3.6382642 ,  9.988962  , 15.394426  ,
#         14.381792  , 16.85863   ],
#        [20.431149  ,  3.666542  ,  0.9494915 , 13.127065  ,  1.0877594 ,
#          3.9682336 ,  8.352703  ],
#        [12.449079  ,  7.4483547 ,  9.020371  , 12.91818   ,  4.660253  ,
#         15.050695  , 17.663895  ],
#        [ 3.6677618 ,  1.8788863 ,  9.630286  , 15.927005  , 12.165615  ,
#          8.372621  ,  3.7931    ],
#        [14.227756  ,  2.8116312 , 14.475865  , 12.499492  ,  9.598626  ,
#          5.1156845 , 10.267806  ],
#        [ 4.472824  , 16.457186  , 10.766223  , 17.367182  ,  5.56736   ,
#          9.721673  , 12.450246  ],
#        [18.415062  ,  5.6823645 , 18.72545   , 12.237684  , 11.6276865 ,
#         10.247247  , 16.45106   ],
#        [ 0.683151  , 18.227896  , 14.194482  , 12.414352  , 18.586168  ,
#          4.3464894 , 14.482239  ],
#        [16.497013  ,  1.1381323 , 17.01231   , 15.54987   , 11.329469  ,
#         10.352557  , 12.92215   ],
#        [16.302843  , 10.601507  ,  1.6599889 ,  9.643506  ,  0.9744912 ,
#         17.93604   ,  5.003346  ],
#        [ 4.5424895 , 14.427296  ,  8.32971   ,  2.9544935 ,  9.011884  ,
#          1.4540335 , 20.08701   ],
#        [ 8.175367  ,  9.772027  ,  5.05194   , 13.426706  ,  4.3672595 ,
#         16.349985  , 16.000717  ],
#        [ 0.8139438 , 15.944617  , 15.418192  ,  5.6061125 ,  6.4740376 ,
#         14.489671  ,  7.3933587 ],
#        [ 2.2884905 ,  3.5951056 , 19.962234  , 15.206375  ,  9.973403  ,
#          8.754494  , 13.954441  ],
#        [ 5.4577518 , 10.142496  , 13.1673355 , 10.261039  ,  8.917501  ,
#         10.9432335 ,  7.757713  ],
#        [12.459389  , 19.186659  , 19.116013  , 15.1693    , 17.091845  ,
#          7.4888234 ,  9.578191  ],
#        [ 7.104676  ,  1.7408813 , 17.182451  , 10.616942  , 16.427832  ,
#         15.611808  , 15.735061  ],
#        [ 4.855047  ,  7.75458   , 19.774082  ,  8.672224  , 10.138478  ,
#         14.843635  , 14.940827  ],
#        [ 5.0569115 , 14.405908  , 14.4064245 ,  6.612095  , 16.168482  ,
#         14.746365  ,  1.1585971 ],
#        [18.753603  ,  9.753741  ,  4.262268  ,  8.686584  , 16.959122  ,
#         16.719265  ,  2.8643105 ],
#        [16.118637  ,  1.9378402 , 14.057248  ,  5.606589  , 10.7623205 ,
#         17.748964  , 10.533603  ],
#        [15.434498  , 10.263688  ,  9.868739  ,  3.481662  ,  4.6253366 ,
#          3.4521368 , 16.53421   ],
#        [15.729704  , 17.38441   ,  2.419475  , 16.768091  , 11.836575  ,
#          7.3701134 ,  2.3015482 ],
#        [17.868528  ,  7.5434737 ,  6.5954723 ,  8.153781  , 10.929962  ,
#          8.995249  , 10.785579  ],
#        [12.979893  ,  2.0870523 , 12.142981  ,  6.415921  , 12.124063  ,
#         16.75628   ,  4.914167  ],
#        [20.121002  ,  8.365026  , 18.657925  , 10.303135  , 11.470375  ,
#          2.0763943 ,  3.6765342 ],
#        [ 2.113437  ,  7.846421  , 16.074553  , 16.80287   ,  9.205989  ,
#          9.218183  , 14.200667  ],
#        [15.44802   , 16.14465   , 15.2001505 , 11.680045  ,  5.2095776 ,
#         17.183334  ,  8.779904  ],
#        [19.066254  , 10.845242  , 17.27746   , 13.628451  , 13.697256  ,
#          7.32668   , 14.085395  ],
#        [13.094273  , 18.240032  ,  2.5655138 ,  7.8461185 ,  3.198279  ,
#          2.835771  , 19.489147  ],
#        [ 7.55877   ,  9.245704  , 13.341898  ,  6.700713  , 15.585852  ,
#         17.015856  ,  1.4181852 ],
#        [ 6.1119595 , 13.815806  ,  3.7278864 ,  3.955231  ,  3.6521444 ,
#          4.075197  ,  3.435711  ],
#        [13.853019  ,  0.39968508,  9.335242  , 14.927655  ,  4.4848695 ,
#         17.073078  , 14.699678  ],
#        [ 4.999157  , 20.078266  ,  7.363084  ,  3.4680018 , 15.686798  ,
#         14.38224   ,  2.5122306 ],
#        [ 5.655714  ,  4.6646914 , 17.644512  ,  7.2840734 ,  8.928352  ,
#          4.2606206 , 15.424705  ],
#        [15.553113  , 10.809999  ,  6.4128733 ,  7.8352003 , 14.525795  ,
#         13.301406  , 20.19608   ],
#        [17.991604  , 16.198332  ,  8.436094  , 19.494324  , 18.566591  ,
#          3.1411514 ,  6.436071  ],
#        [ 6.9671326 , 13.461496  ,  9.396859  ,  1.2902055 , 12.806725  ,
#         15.58196   ,  6.7190824 ],
#        [ 1.6951822 , 10.481511  , 18.40385   , 17.909092  , 14.700512  ,
#          6.1320615 , 18.62023   ],
#        [ 3.61289   , 11.271715  ,  2.6763806 ,  7.3496466 ,  4.9760017 ,
#          0.87106925, 16.618021  ],
#        [14.672194  , 16.770428  , 14.427155  ,  6.4865627 , 14.612798  ,
#          7.0787873 , 17.500292  ],
#        [11.808387  , 19.725657  ,  3.607774  ,  1.7104543 , 13.155799  ,
#         20.458282  , 10.1435375 ],
#        [11.317833  ,  5.9202223 , 19.9395    ,  9.103918  , 14.354355  ,
#         12.466886  , 20.428015  ],
#        [ 2.209112  ,  6.4071026 ,  1.9421623 ,  5.690899  , 17.33768   ,
#         10.758816  ,  7.6300473 ],
#        [ 2.3044074 ,  4.6026154 ,  7.4207425 , 12.717592  , 16.409058  ,
#         19.753702  , 17.880264  ],
#        [11.751952  ,  1.5077777 , 18.152632  , 11.16966   ,  1.734255  ,
#         14.192648  , 10.989309  ],
#        [17.099852  , 12.544575  ,  8.404485  , 11.708167  ,  3.883413  ,
#         19.952583  , 13.362533  ],
#        [ 8.201308  , 10.051513  , 16.321793  ,  2.5373147 , 10.407606  ,
#         19.416216  ,  2.5222034 ],
#        [13.955969  ,  9.840014  ,  7.795982  ,  4.0137315 ,  2.971019  ,
#         16.424265  , 16.345509  ]], dtype=float32)

# %%
def build_model():
    
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True), input_shape=(7, 1)))

    model.add(tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True)))
    
    model.add(tf.keras.layers.GRU(64, return_sequences=True, kernel_initializer='uniform'))
    model.add(tf.keras.layers.Dropout(0.2))
    
    model.add(tf.keras.layers.GRU(32, return_sequences=True, kernel_initializer='uniform'))
    model.add(tf.keras.layers.Dropout(0.2))


    model.add(tf.keras.layers.Flatten())
    
    model.add(tf.keras.layers.Dense(32, activation='relu'))
    model.add(tf.keras.layers.Dense(7))
    
    model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 0.001), loss = 'mae', metrics=['mse'])

    model.summary()
    
    return model

# %%
save_best = tf.keras.callbacks.ModelCheckpoint("Model.h5", monitor='val_loss',verbose=1, save_best_only=True)

# %%
model = build_model()
model.fit(X_train, y_train, validation_data=(X_test,y_test), epochs=40, batch_size=128, verbose=1, callbacks=[save_best])
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_22 (Bidirecti  (None, 7, 128)           33792
#  onal)
#
#  bidirectional_23 (Bidirecti  (None, 7, 64)            41216
#  onal)
#
#  gru_4 (GRU)                 (None, 7, 64)             24960
#
#  dropout_6 (Dropout)         (None, 7, 64)             0
#
#  gru_5 (GRU)                 (None, 7, 32)             9408
#
#  dropout_7 (Dropout)         (None, 7, 32)             0
#
#  flatten_8 (Flatten)         (None, 224)               0
#
#  dense_16 (Dense)            (None, 32)                7200
#
#  dense_17 (Dense)            (None, 7)                 231
#
# =================================================================
# Total params: 116,807
# Trainable params: 116,807
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 1/1 [==============================] - ETA: 0s - loss: 10.3447 - mse: 139.7321
# Epoch 1: val_loss improved from inf to 11.25733, saving model to Model.h5
# 1/1 [==============================] - 14s 14s/step - loss: 10.3447 - mse: 139.7321 - val_loss: 11.2573 - val_mse: 153.4414
# Epoch 2/40
# 1/1 [==============================] - ETA: 0s - loss: 10.3349 - mse: 139.5191
# Epoch 2: val_loss improved from 11.25733 to 11.24682, saving model to Model.h5
# 1/1 [==============================] - 0s 113ms/step - loss: 10.3349 - mse: 139.5191 - val_loss: 11.2468 - val_mse: 153.2022
# Epoch 3/40
# 1/1 [==============================] - ETA: 0s - loss: 10.3246 - mse: 139.3107
# Epoch 3: val_loss improved from 11.24682 to 11.23340, saving model to Model.h5
# 1/1 [==============================] - 0s 126ms/step - loss: 10.3246 - mse: 139.3107 - val_loss: 11.2334 - val_mse: 152.9005
# Epoch 4/40
# 1/1 [==============================] - ETA: 0s - loss: 10.3108 - mse: 139.0241
# Epoch 4: val_loss improved from 11.23340 to 11.21539, saving model to Model.h5
# 1/1 [==============================] - 0s 112ms/step - loss: 10.3108 - mse: 139.0241 - val_loss: 11.2154 - val_mse: 152.4976
# Epoch 5/40
# 1/1 [==============================] - ETA: 0s - loss: 10.2927 - mse: 138.6494
# Epoch 5: val_loss improved from 11.21539 to 11.19073, saving model to Model.h5
# 1/1 [==============================] - 0s 122ms/step - loss: 10.2927 - mse: 138.6494 - val_loss: 11.1907 - val_mse: 151.9496
# Epoch 6/40
# 1/1 [==============================] - ETA: 0s - loss: 10.2687 - mse: 138.1605
# Epoch 6: val_loss improved from 11.19073 to 11.15612, saving model to Model.h5
# 1/1 [==============================] - 0s 124ms/step - loss: 10.2687 - mse: 138.1605 - val_loss: 11.1561 - val_mse: 151.1878
# Epoch 7/40
# 1/1 [==============================] - ETA: 0s - loss: 10.2347 - mse: 137.4599
# Epoch 7: val_loss improved from 11.15612 to 11.10929, saving model to Model.h5
# 1/1 [==============================] - 0s 113ms/step - loss: 10.2347 - mse: 137.4599 - val_loss: 11.1093 - val_mse: 150.1672
# Epoch 8/40
# 1/1 [==============================] - ETA: 0s - loss: 10.1868 - mse: 136.4825
# Epoch 8: val_loss improved from 11.10929 to 11.04468, saving model to Model.h5
# 1/1 [==============================] - 0s 131ms/step - loss: 10.1868 - mse: 136.4825 - val_loss: 11.0447 - val_mse: 148.7679
# Epoch 9/40
# 1/1 [==============================] - ETA: 0s - loss: 10.1274 - mse: 135.3110
# Epoch 9: val_loss improved from 11.04468 to 10.95828, saving model to Model.h5
# 1/1 [==============================] - 0s 121ms/step - loss: 10.1274 - mse: 135.3110 - val_loss: 10.9583 - val_mse: 146.9125
# Epoch 10/40
# 1/1 [==============================] - ETA: 0s - loss: 10.0348 - mse: 133.4114
# Epoch 10: val_loss improved from 10.95828 to 10.84746, saving model to Model.h5
# 1/1 [==============================] - 0s 132ms/step - loss: 10.0348 - mse: 133.4114 - val_loss: 10.8475 - val_mse: 144.5271
# Epoch 11/40
# 1/1 [==============================] - ETA: 0s - loss: 9.9387 - mse: 131.6121
# Epoch 11: val_loss improved from 10.84746 to 10.70880, saving model to Model.h5
# 1/1 [==============================] - 0s 136ms/step - loss: 9.9387 - mse: 131.6121 - val_loss: 10.7088 - val_mse: 141.5148
# Epoch 12/40
# 1/1 [==============================] - ETA: 0s - loss: 9.7880 - mse: 128.7779
# Epoch 12: val_loss improved from 10.70880 to 10.54184, saving model to Model.h5
# 1/1 [==============================] - 0s 138ms/step - loss: 9.7880 - mse: 128.7779 - val_loss: 10.5418 - val_mse: 137.8317
# Epoch 13/40
# 1/1 [==============================] - ETA: 0s - loss: 9.6022 - mse: 125.0659
# Epoch 13: val_loss improved from 10.54184 to 10.34507, saving model to Model.h5
# 1/1 [==============================] - 0s 132ms/step - loss: 9.6022 - mse: 125.0659 - val_loss: 10.3451 - val_mse: 133.4853
# Epoch 14/40
# 1/1 [==============================] - ETA: 0s - loss: 9.3877 - mse: 120.9310
# Epoch 14: val_loss improved from 10.34507 to 10.11434, saving model to Model.h5
# 1/1 [==============================] - 0s 133ms/step - loss: 9.3877 - mse: 120.9310 - val_loss: 10.1143 - val_mse: 128.5582
# Epoch 15/40
# 1/1 [==============================] - ETA: 0s - loss: 9.1611 - mse: 116.7539
# Epoch 15: val_loss improved from 10.11434 to 9.85962, saving model to Model.h5
# 1/1 [==============================] - 0s 124ms/step - loss: 9.1611 - mse: 116.7539 - val_loss: 9.8596 - val_mse: 123.2225
# Epoch 16/40
# 1/1 [==============================] - ETA: 0s - loss: 8.8927 - mse: 112.3886
# Epoch 16: val_loss improved from 9.85962 to 9.59243, saving model to Model.h5
# 1/1 [==============================] - 0s 134ms/step - loss: 8.8927 - mse: 112.3886 - val_loss: 9.5924 - val_mse: 117.6829
# Epoch 17/40
# 1/1 [==============================] - ETA: 0s - loss: 8.6356 - mse: 107.2846
# Epoch 17: val_loss improved from 9.59243 to 9.32517, saving model to Model.h5
# 1/1 [==============================] - 0s 120ms/step - loss: 8.6356 - mse: 107.2846 - val_loss: 9.3252 - val_mse: 112.1294
# Epoch 18/40
# 1/1 [==============================] - ETA: 0s - loss: 8.3470 - mse: 101.5966
# Epoch 18: val_loss improved from 9.32517 to 9.05367, saving model to Model.h5
# 1/1 [==============================] - 0s 125ms/step - loss: 8.3470 - mse: 101.5966 - val_loss: 9.0537 - val_mse: 106.6879
# Epoch 19/40
# 1/1 [==============================] - ETA: 0s - loss: 8.1139 - mse: 97.4057
# Epoch 19: val_loss improved from 9.05367 to 8.79289, saving model to Model.h5
# 1/1 [==============================] - 0s 120ms/step - loss: 8.1139 - mse: 97.4057 - val_loss: 8.7929 - val_mse: 101.4117
# Epoch 20/40
# 1/1 [==============================] - ETA: 0s - loss: 7.8775 - mse: 92.9309
# Epoch 20: val_loss improved from 8.79289 to 8.55111, saving model to Model.h5
# 1/1 [==============================] - 0s 117ms/step - loss: 7.8775 - mse: 92.9309 - val_loss: 8.5511 - val_mse: 96.3360
# Epoch 21/40
# 1/1 [==============================] - ETA: 0s - loss: 7.6787 - mse: 88.9696
# Epoch 21: val_loss improved from 8.55111 to 8.31442, saving model to Model.h5
# 1/1 [==============================] - 0s 119ms/step - loss: 7.6787 - mse: 88.9696 - val_loss: 8.3144 - val_mse: 91.5380
# Epoch 22/40
# 1/1 [==============================] - ETA: 0s - loss: 7.4816 - mse: 84.8702
# Epoch 22: val_loss improved from 8.31442 to 8.07560, saving model to Model.h5
# 1/1 [==============================] - 0s 115ms/step - loss: 7.4816 - mse: 84.8702 - val_loss: 8.0756 - val_mse: 86.9568
# Epoch 23/40
# 1/1 [==============================] - ETA: 0s - loss: 7.2371 - mse: 79.7575
# Epoch 23: val_loss improved from 8.07560 to 7.83630, saving model to Model.h5
# 1/1 [==============================] - 0s 117ms/step - loss: 7.2371 - mse: 79.7575 - val_loss: 7.8363 - val_mse: 82.5786
# Epoch 24/40
# 1/1 [==============================] - ETA: 0s - loss: 7.0907 - mse: 76.5309
# Epoch 24: val_loss improved from 7.83630 to 7.60216, saving model to Model.h5
# 1/1 [==============================] - 0s 118ms/step - loss: 7.0907 - mse: 76.5309 - val_loss: 7.6022 - val_mse: 78.3933
# Epoch 25/40
# 1/1 [==============================] - ETA: 0s - loss: 6.9657 - mse: 74.0000
# Epoch 25: val_loss improved from 7.60216 to 7.37439, saving model to Model.h5
# 1/1 [==============================] - 0s 125ms/step - loss: 6.9657 - mse: 74.0000 - val_loss: 7.3744 - val_mse: 74.3633
# Epoch 26/40
# 1/1 [==============================] - ETA: 0s - loss: 6.8020 - mse: 69.7249
# Epoch 26: val_loss improved from 7.37439 to 7.14969, saving model to Model.h5
# 1/1 [==============================] - 0s 108ms/step - loss: 6.8020 - mse: 69.7249 - val_loss: 7.1497 - val_mse: 70.4735
# Epoch 27/40
# 1/1 [==============================] - ETA: 0s - loss: 6.6728 - mse: 66.6433
# Epoch 27: val_loss improved from 7.14969 to 6.92987, saving model to Model.h5
# 1/1 [==============================] - 0s 116ms/step - loss: 6.6728 - mse: 66.6433 - val_loss: 6.9299 - val_mse: 66.7242
# Epoch 28/40
# 1/1 [==============================] - ETA: 0s - loss: 6.5004 - mse: 62.9051
# Epoch 28: val_loss improved from 6.92987 to 6.72150, saving model to Model.h5
# 1/1 [==============================] - 0s 124ms/step - loss: 6.5004 - mse: 62.9051 - val_loss: 6.7215 - val_mse: 63.1495
# Epoch 29/40
# 1/1 [==============================] - ETA: 0s - loss: 6.3782 - mse: 60.2136
# Epoch 29: val_loss improved from 6.72150 to 6.52134, saving model to Model.h5
# 1/1 [==============================] - 0s 110ms/step - loss: 6.3782 - mse: 60.2136 - val_loss: 6.5213 - val_mse: 59.7323
# Epoch 30/40
# 1/1 [==============================] - ETA: 0s - loss: 6.2541 - mse: 57.9545
# Epoch 30: val_loss improved from 6.52134 to 6.32778, saving model to Model.h5
# 1/1 [==============================] - 0s 113ms/step - loss: 6.2541 - mse: 57.9545 - val_loss: 6.3278 - val_mse: 56.4818
# Epoch 31/40
# 1/1 [==============================] - ETA: 0s - loss: 6.1489 - mse: 55.2368
# Epoch 31: val_loss improved from 6.32778 to 6.13946, saving model to Model.h5
# 1/1 [==============================] - 0s 127ms/step - loss: 6.1489 - mse: 55.2368 - val_loss: 6.1395 - val_mse: 53.4199
# Epoch 32/40
# 1/1 [==============================] - ETA: 0s - loss: 6.0453 - mse: 53.1037
# Epoch 32: val_loss improved from 6.13946 to 5.96677, saving model to Model.h5
# 1/1 [==============================] - 0s 108ms/step - loss: 6.0453 - mse: 53.1037 - val_loss: 5.9668 - val_mse: 50.5599
# Epoch 33/40
# 1/1 [==============================] - ETA: 0s - loss: 5.9132 - mse: 50.5487
# Epoch 33: val_loss improved from 5.96677 to 5.80550, saving model to Model.h5
# 1/1 [==============================] - 0s 110ms/step - loss: 5.9132 - mse: 50.5487 - val_loss: 5.8055 - val_mse: 47.9103
# Epoch 34/40
# 1/1 [==============================] - ETA: 0s - loss: 5.8401 - mse: 49.0450
# Epoch 34: val_loss improved from 5.80550 to 5.64946, saving model to Model.h5
# 1/1 [==============================] - 0s 122ms/step - loss: 5.8401 - mse: 49.0450 - val_loss: 5.6495 - val_mse: 45.4733
# Epoch 35/40
# 1/1 [==============================] - ETA: 0s - loss: 5.7002 - mse: 46.7933
# Epoch 35: val_loss improved from 5.64946 to 5.50711, saving model to Model.h5
# 1/1 [==============================] - 0s 113ms/step - loss: 5.7002 - mse: 46.7933 - val_loss: 5.5071 - val_mse: 43.2384
# Epoch 36/40
# 1/1 [==============================] - ETA: 0s - loss: 5.6292 - mse: 45.2316
# Epoch 36: val_loss improved from 5.50711 to 5.38055, saving model to Model.h5
# 1/1 [==============================] - 0s 123ms/step - loss: 5.6292 - mse: 45.2316 - val_loss: 5.3806 - val_mse: 41.2091
# Epoch 37/40
# 1/1 [==============================] - ETA: 0s - loss: 5.5709 - mse: 44.1810
# Epoch 37: val_loss improved from 5.38055 to 5.26421, saving model to Model.h5
# 1/1 [==============================] - 0s 121ms/step - loss: 5.5709 - mse: 44.1810 - val_loss: 5.2642 - val_mse: 39.3668
# Epoch 38/40
# 1/1 [==============================] - ETA: 0s - loss: 5.4878 - mse: 42.5478
# Epoch 38: val_loss improved from 5.26421 to 5.15429, saving model to Model.h5
# 1/1 [==============================] - 0s 124ms/step - loss: 5.4878 - mse: 42.5478 - val_loss: 5.1543 - val_mse: 37.6998
# Epoch 39/40
# 1/1 [==============================] - ETA: 0s - loss: 5.4478 - mse: 41.6176
# Epoch 39: val_loss improved from 5.15429 to 5.05300, saving model to Model.h5
# 1/1 [==============================] - 0s 122ms/step - loss: 5.4478 - mse: 41.6176 - val_loss: 5.0530 - val_mse: 36.1879
# Epoch 40/40
# 1/1 [==============================] - ETA: 0s - loss: 5.3940 - mse: 40.6424
# Epoch 40: val_loss improved from 5.05300 to 4.96013, saving model to Model.h5
# 1/1 [==============================] - 0s 153ms/step - loss: 5.3940 - mse: 40.6424 - val_loss: 4.9601 - val_mse: 34.8234

# %% [markdown]
# ---

# %%
test = np.array([18.31,16.44,18.23,15.65,17.67,16.75,19.34]).astype(np.float32)
pred = model.predict(test.reshape(1,7))

graphPrediction = []
graphPrediction.extend(test)
graphPrediction.extend(pred.reshape(-1))

x = []
for i in range(14):
    x.append(i)

# Create a line plot with two colors
plt.figure(figsize=(10, 6))

# Plot the first segment of the line in blue
plt.plot(x[:7], graphPrediction[:7], color='blue', linestyle='-', linewidth=2, label='Input')

# Plot the second segment of the line in red
plt.plot(x[7:], graphPrediction[7:], color='red', linestyle='--', linewidth=2, label='AI Predicted')

# Customize plot elements
plt.title('Line Plot with Two Colors')
plt.xlabel('Days')
plt.ylabel('Carbon Emit')
plt.grid(True)
plt.legend()

# Show the plot
plt.show()
# Out:
# 1/1 [==============================] - 0s 21ms/step

# %%
test = np.array([17.582363,  9.527162, 20.918768, 11.207062,  9.265643, 8.97169 ,
        7.311791]).astype(np.float32)
pred = model.predict(test.reshape(1,7))

graphPrediction = []
graphPrediction.extend(test)
graphPrediction.extend(pred.reshape(-1))

x = []
for i in range(14):
    x.append(i)

# Create a line plot with two colors
plt.figure(figsize=(10, 6))

# Plot the first segment of the line in blue
plt.plot(x[:7], graphPrediction[:7], color='blue', linestyle='-', linewidth=2, label='Input')

# Plot the second segment of the line in red
plt.plot(x[7:], graphPrediction[7:], color='red', linestyle='--', linewidth=2, label='AI Predicted')

# Customize plot elements
plt.title('Line Plot with Two Colors')
plt.xlabel('Days')
plt.ylabel('Carbon Emit')
plt.grid(True)
plt.legend()

# Show the plot
plt.show()
# Out:
# 1/1 [==============================] - 0s 31ms/step

# %% [markdown]
# ---
